# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
data = pd.read_csv("./data.csv")

# %%
data.head()
# Out:
#           make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0  alfa-romero       gas        std          two  convertible          rwd
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two    hatchback          rwd
# 3         audi       gas        std         four        sedan          fwd
# 4         audi       gas        std         four        sedan          4wd
#
#   engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 0           front        88.6   168.8   64.1  ...          130         mpfi
# 1           front        88.6   168.8   64.1  ...          130         mpfi
# 2           front        94.5   171.2   65.5  ...          152         mpfi
# 3           front        99.8   176.6   66.2  ...          109         mpfi
# 4           front        99.4   176.6   66.4  ...          136         mpfi
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               193 non-null    int8
#  1   fuel-type          193 non-null    int8
#  2   aspiration         193 non-null    int8
#  3   num-of-doors       193 non-null    int8
#  4   body-style         193 non-null    int8
#  5   drive-wheels       193 non-null    int8
#  6   engine-location    193 non-null    int8
#  7   wheel-base         193 non-null    float64
#  8   length             193 non-null    float64
#  9   width              193 non-null    float64
#  10  height             193 non-null    float64
#  11  curb-weight        193 non-null    int64
#  12  engine-type        193 non-null    int8
#  13  num-of-cylinders   193 non-null    int8
#  14  engine-size        193 non-null    int64
#  15  fuel-system        193 non-null    int8
# ...

# %%
t_list = data['fuel-type'].unique()

# %%
t_list
# Out:
# array([1, 0], dtype=int8)

# %%
cat_col = data.select_dtypes(['object']).columns

for i in cat_col:
    t_list = data[i].unique()
    counter = 0
    for j in t_list:
        data[i][data[i] == j] = counter
        counter = counter + 1 
    data[i] = data[i].astype('int')
# Out:
# c:\users\mahdi\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               193 non-null    int32
#  1   fuel-type          193 non-null    int32
#  2   aspiration         193 non-null    int32
#  3   num-of-doors       193 non-null    int32
#  4   body-style         193 non-null    int32
#  5   drive-wheels       193 non-null    int32
#  6   engine-location    193 non-null    int32
#  7   wheel-base         193 non-null    float64
#  8   length             193 non-null    float64
#  9   width              193 non-null    float64
#  10  height             193 non-null    float64
#  11  curb-weight        193 non-null    int64
#  12  engine-type        193 non-null    int32
#  13  num-of-cylinders   193 non-null    int32
#  14  engine-size        193 non-null    int64
#  15  fuel-system        193 non-null    int32
# ...

# %%
cat_col = data.select_dtypes(['object']).columns

# %%
for i in cat_col:
    data[i] = data[i].astype('category')
    data[i] = data[i].cat.codes

# %%
data.head()
# Out:
#    make  fuel-type  aspiration  num-of-doors  body-style  drive-wheels  \
# 0     0          1           0             1           0             2
# 1     0          1           0             1           0             2
# 2     0          1           0             1           2             2
# 3     1          1           0             0           3             1
# 4     1          1           0             0           3             0
#
#    engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 0                0        88.6   168.8   64.1  ...          130            4
# 1                0        88.6   168.8   64.1  ...          130            4
# 2                0        94.5   171.2   65.5  ...          152            4
# 3                0        99.8   176.6   66.2  ...          109            4
# 4                0        99.4   176.6   66.4  ...          136            4
#
#    bore  stroke  compression-ratio  horsepower  peak-rpm  city-mpg  \
# ...

# %%
data = pd.read_csv('data.csv')

le = LabelEncoder()
cat_cols = data.select_dtypes(include=['object']).columns
data[cat_cols] = data[cat_cols].apply(lambda col: le.fit_transform(col.astype(str)))

# %%
data.head()
# Out:
#    make  fuel-type  aspiration  num-of-doors  body-style  drive-wheels  \
# 0     0          1           0             1           0             2
# 1     0          1           0             1           0             2
# 2     0          1           0             1           2             2
# 3     1          1           0             0           3             1
# 4     1          1           0             0           3             0
#
#    engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 0                0        88.6   168.8   64.1  ...          130            4
# 1                0        88.6   168.8   64.1  ...          130            4
# 2                0        94.5   171.2   65.5  ...          152            4
# 3                0        99.8   176.6   66.2  ...          109            4
# 4                0        99.4   176.6   66.4  ...          136            4
#
#    bore  stroke  compression-ratio  horsepower  peak-rpm  city-mpg  \
# ...

# %%
y = data['price']
data.drop(["price"],axis = 1)
x = data

# %%
data.head()
# Out:
#    make  fuel-type  aspiration  num-of-doors  body-style  drive-wheels  \
# 0     0          1           0             1           0             2
# 1     0          1           0             1           0             2
# 2     0          1           0             1           2             2
# 3     1          1           0             0           3             1
# 4     1          1           0             0           3             0
#
#    engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 0                0        88.6   168.8   64.1  ...          130            4
# 1                0        88.6   168.8   64.1  ...          130            4
# 2                0        94.5   171.2   65.5  ...          152            4
# 3                0        99.8   176.6   66.2  ...          109            4
# 4                0        99.4   176.6   66.4  ...          136            4
#
#    bore  stroke  compression-ratio  horsepower  peak-rpm  city-mpg  \
# ...

# %%
cols = data.columns

# %%
y = data["price"]
x = data[cols[:-1]]

# %%
x
# Out:
#      make  fuel-type  aspiration  num-of-doors  body-style  drive-wheels  \
# 0       0          1           0             1           0             2
# 1       0          1           0             1           0             2
# 2       0          1           0             1           2             2
# 3       1          1           0             0           3             1
# 4       1          1           0             0           3             0
# ..    ...        ...         ...           ...         ...           ...
# 188    20          1           0             0           3             2
# 189    20          1           1             0           3             2
# 190    20          1           0             0           3             2
# 191    20          0           1             0           3             2
# 192    20          1           1             0           3             2
#
#      engine-location  wheel-base  length  width  ...  num-of-cylinders  \
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, shuffle=True ,test_size=0.2)

# %%
regressor=LinearRegression()  
res_train = regressor.fit(x_train,y_train)

# %%
y_predict = regressor.predict(x_test) 
r2_score(y_test,y_predict)
# Out:
# 0.7105813543370142
